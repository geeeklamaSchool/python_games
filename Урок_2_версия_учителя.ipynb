# %% [markdown]
# # <span style = "color: teal"> План урока 2 </span>
#
# <span style = "color: teal"> Сегодня мы познакомим учащихся с классами. Мы должны показать им общую идею классов и научить их создавать какой-нибудь простой класс и как с ним работать. Это важно для их общего обзора. Кроме того, знания о классах необходимы для понимания кодов библиотеки аркадных игр. Мы представим класс _arcade.Window_ и пару методов из этого класса. Поэтому в конце этого урока мы начинаем плотно работать с аркадной библиотекой! <br>
#
#
# - Занятия: вступление ~ 10 мин.
# - Занятия: атрибуты ~ 18 мин.
# - Аркадная библиотека: класс _arcade.Window_ ~ 17 мин.
# - Библиотека аркад: взаимодействие пользователя с клавиатурой ~ 5 мин.
# - Объяснение домашней работы ~ 10 мин.
#
# <span style = "color: teal"> В первой части этого урока нет больших кодов; поэтому убедитесь, что учащиеся вводят код в ячейки. Это помогает им лучше понимать и запоминать синаксис классов. Есть большие фрагменты кода, которые студенты могут скопировать, когда мы перейдем в аркадную библиотеку. Во время урока учитель также большую часть времени набирает код. Когда есть какая-то повторяющаяся часть кода, учитель показывает, где уместно скопировать и вставить код. <br>
# Часто, когда мы запускаем что-то несколько раз, не закрывая, или делаем что-то еще, что не нравится python, это может выдать ошибку, например, 'b invalid operation' или какая-то другая неизвестная ошибка. Перезагрузка ядра помогает. Просто нужно убедиться, что они снова импортируют библиотеку (она включена почти в каждую ячейку, но все же напомните об этом студентам).

# %% [markdown]
# ![image](./Images/lesson2_rus_2.png)
#
# __<CENTER> <span style="color:goldenrod">  Верни свой кошелек! </span><CENTER>__

# %% [markdown]
# # __<span style = "color: Maroon"> Классы: Введение </span>__
#
# **<span style = "color: teal"> Скажите: на последнем уроке вы узнали о функциях, и теперь вы знаете, насколько полезными могут быть эти функции. Иногда мы передаем функции много параметров, и эти параметры могут описывать один объект. Например, давайте посмотрим на мяч. Существует много разных типов мячей, и у них есть некоторые характеристики, которые делают каждый мяч уникальным, например размер, цвет, назначение, вес, материал и т. Д. Кроме того, мы можем выполнять определенные действия с мячом, такие как вычисление площади его поверхности. В программировании мы придумали так называемые классы, которые похожи на шаблон для некоторых конкретных объектов. Мы можем создать класс Ball. Используя этот шаблон Ball, мы можем создать множество уникальных шаров. </span>**
#
# **<span style = "color: teal"> Во время урока в незаполненной тетради заполните текст, который здесь показан другим оттенком зеленого. </span>**
#
# **Класс** - Конструктор или «шаблон» для объекта с определенными атрибутами (переменными и функциями)
#
# **<span style = "color: teal"> Сообщите учащимся, что им может показаться неясным, что такое классы, но по мере продвижения они поймут общую идею и цель классов. </span>**
#
# **<span style = "color: teal"> Обратите внимание на то, что имена классов начинаются с заглавной буквы. Это правило, с которым согласились жители острова. Функции и переменные начинаются с буквы в нижнем регистре, а классы - с буквы в верхнем регистре. Это помогает различать классы в коде. </span>**
#
# Название класса начинается с заглавной буквы.
#
# **<span style = "color: teal"> Мы создадим класс мяча и разработаем класс мяча (добавим различные атрибуты) по мере того, как узнаем больше о классах </span>**
#
# Создадим класс мяча:
# ```python
# class Ball:
#     """
#     This is a class that represents the ball.
#     """
# ```
#
# __<span style = "color: MidnightBlue"> P.S. </span>__ На острове мы не уважаем людей, которые не комментируют свой код!

# %%
#Ваш код тут
class Ball:
    """
    Это класс, представляющий мяч.
    """
#

# %% [markdown]
# **<span style = "color: teal"> Точно так же, как при создании функции, код ничего не делает до тех пор, пока функция не будет вызвана, и до того, как мы создадим экземпляр класса, мы ничего не сможем сделать с классом. Чтобы создать экземпляр класса, мы должны присвоить класс переменной. </span>**
#
# **<span style = "color: teal"> Во время урока в незаполненной тетради заполните текст, который здесь показан другим оттенком зеленого. </span>**
#
# **Объект** - экземпляр класса
#
# Чтобы создать тип объекта:
# ```python
# firstBall = Ball()
# ```
#
# __<span style = "color: MidnightBlue"> P.S. </span>__ Не забывайте ставить круглые скобки после имени класса! На острове важен синтаксис!

# %%
#Ваш код тут
firstBall = Ball()
#

# %% [markdown]
# **<span style = "color: teal"> Опять же, ничего не происходит... У нашего класса еще нет атрибутов. Давайте проверим тип переменной, которую мы определили </span>**
#
# Запустите приведенный ниже код, чтобы изучить тип переменной _firstBall_.

# %%
print(type(1))
print(type('строка'))
print(type([1,3,4]))
print(type(firstBall))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'list'>
# <class '__main__.Ball'>

# %% [markdown]
# ## <center><span style = "color: goldenrod">Что вы наблюдаете?</span>
#
# **<span style = "color: teal"> Каждый раз спрашивайте другого учащегося. <br> </span>**
#
# __<center> 1. Какие наблюдения основаны на приведенном выше коде? <br>__
#
# **<span style = "color: teal"> Главное здесь в том, что некоторые типы, с которыми студенты уже знакомы, на самом деле являются классами. Скажите студентам, что «string» на самом деле является классом. Каждый раз, когда мы создаем новую строку, мы создаем новый объект типа string. Все строки имеют общие свойства `string`, но каждая строка также уникальна по своей структуре. Та же история с целыми числами, списками и другими типами переменных. По сути, когда мы создаем класс, мы создаем тип переменной. <br> </span>**
# __<center> 2. Какой тип у переменной _firstBall_?<br>__
#
# **<span style = "color: teal"> Здесь мы не обращаем внимания на часть `__main__`. Студенты должны понимать, что тип нашей переменной - _Ball_ <br> </span>**
#
# __<center> 3. Поможет ли класс в выполнении вашей последней домашней работы? Как? <br>__
#
# **<span style = "color: teal"> Им нужно было собрать три «атрибута» о каждом ученике. Каждый студент мог быть отдельным объектом студенческого класса. Поэтому каждый раз, когда мы получаем информацию от пользователя о новом ученике, мы создаем новый объект ученика.<br></span>**
#
# ![image](./Images/diss.png)

# %% [markdown]
# # __<span style = "color: Maroon"> Классы: атрибуты </span>__
#
# **<span style = "color: teal"> Классы обычно могут иметь два типа атрибутов - функции и переменные. Могут быть и другие атрибуты, связанные с классами, но мы не будем углубляться в объектно-ориентированное программирование.<br> </span>**
#
# Атрибуты класса могут включать переменные и функции.
#
# **<span style = "color: teal"> Помните, у нас были глобальные и локальные переменные? в классах мы можем иметь атрибуты класса и экземпляра. <br> </span>**
#
# **<span style = "color: teal"> Во время урока в незаполненной тетради заполните текст, который здесь показан другим оттенком зеленого.</span>**
#
# - Атрибут класса - каждый объект, созданный с помощью класса, имеет этот атрибут
# - Атрибут экземпляра - уникальный атрибут для каждого объекта
#
# **<span style = "color: teal"> Скажите: давайте исследуем. Наш класс выглядит пустым, поэтому давайте добавим пару атрибутов, таких как цвет, материал и размер (радиус). <br> </span>**
#
# Атрибуты класса обозначаются через точку - `ObjectName.Attribute`. Пример: alist.append().
#
# **<span style = "color: teal"> Напомните учащимся, что мы уже использовали синтаксис с точкой. Теперь ученики знают, что значит вызывать что-либо через точку. <br> </span>**
#
# В приведенном ниже коде мы добавили к нашему классу пару атрибутов. Обратите внимание на то, что отображается в коде.

# %%
class Ball:
    """
    Это класс, представляющий мяч.
    """
    color = 'Синий'
    radius = 5
    material = 'Кожа'
    
newBall = Ball()
print('newBall - Цвет: ', newBall.color,', радиус: ', newBall.radius)
print()

football = Ball()
football.color = 'черный&белый'
print('football - Цвет: ', football.color,', радиус: ', football.radius)
print('newBall - Цвет: ', newBall.color,', радиус: ', newBall.radius)
print()

Ball.radius = 8
print('football - Цвет: ', football.color,', радиус: ', football.radius)
print('newBall - Цвет: ', newBall.color,', радиус: ', newBall.radius)
# Out:
# newBall - Цвет:  Синий , радиус:  5
#
# football - Цвет:  черный&белый , радиус:  5
# newBall - Цвет:  Синий , радиус:  5
#
# football - Цвет:  черный&белый , радиус:  8
# newBall - Цвет:  Синий , радиус:  8

# %% [markdown]
# ## <center> <span style = "color: goldenrod"> Что вы наблюдаете? </span>
#
# **<span style = "color: teal"> Каждый раз задавайте вопрос другому учащемуся. <br> </span>**
#
# __<center> 1. Сколько объектов было создано? <br>__
#
# **<span style = "color: teal"> Мы создали только два объекта. <br></span>**
#
# __<center> 2. Найдите переменные экземпляра и класса. <br>__
#
# **<span style = "color: teal"> Вообще, мы создали только одну переменную экземпляра, когда изменили атрибут _color_ в объекте _football_. <br> </span>**
#
# __<center> 3. Как появилась переменная экземпляра? <br>__
#
# **<span style = "color: teal"> Мы присвоили новое значение в объекте _football_ переменной _color_. <br></span>**
#
# __<center> 4. Что произойдет, если мы изменим переменную непосредственно в классе? <br>__
#
# **<span style = "color: teal"> Значение этого атрибута изменяется во всех существующих объектах. Важно понимать, что все объекты относятся к классу, но они не зависят от других объектов, созданных этим классом. <br></span>**
#
# **<span style = "color: teal"> Дайте учащимся возможность задать несколько дополнительных вопросов и поделиться некоторыми дополнительными наблюдениями. <br></span>**
# ![image](./Images/diss.png)

# %% [markdown]
# **<span style = "color: teal"> Жители острова согласились использовать специальную функцию для инициализации атрибутов переменных - функцию `__init __()`. Это особая функция, у которой есть особое имя. Убедитесь, что учащиеся понимают важность двойного подчеркивания. Эта функция всегда выполняется после создания объекта (нам не нужно вызывать ее с точкой, как нам приходится вызывать все остальные атрибуты). <br> </span>**
#
# `__init__()` - специальная функция, которая используется для инициализации класса, например, для присвоения значений переменным. Эта функция всегда выполняется после создания объекта.
#
# **<span style = "color: teal"> Класс Ball в приведенном ниже коде имеет те же атрибуты, что и класс Ball, который мы создали ранее. <br> </span>**

# %%
class Ball:
    """
    Это класс, представляющий мяч
    """
    def __init__(self, color, radius):
        """ Этот метод задает значения переменных в объекте """
        self.color = color
        self.radius = radius
        self.material = 'Кожа'

ball_1 = Ball('Синий',10)
ball_2 = Ball('Зеленый', 14)
ball_3 = Ball('Белый', 7)
ball_3.material = 'Резина'

print('ball_1 - Цвет: ', ball_1.color,', радиус: ', ball_1.radius,', материал: ', ball_1.material)
print('ball_2 - Цвет: ', ball_2.color,', радиус: ', ball_2.radius,', материал: ', ball_2.material)
print('ball_3 - Цвет: ', ball_3.color,', радиус: ', ball_3.radius,', материал: ', ball_3.material)
print()
ball_1.color = 'Черный'
print('ball_1 - Цвет: ', ball_1.color,', радиус: ', ball_1.radius,', материал: ', ball_1.material)
# Out:
# ball_1 - Цвет:  Синий , радиус:  10 , материал:  Кожа
# ball_2 - Цвет:  Зеленый , радиус:  14 , материал:  Кожа
# ball_3 - Цвет:  Белый , радиус:  7 , материал:  Резина
#
# ball_1 - Цвет:  Черный , радиус:  10 , материал:  Кожа

# %% [markdown]
# **<span style = "color: teal"> Просмотрите код и покажите, что это намного проще, когда мы создаем объекты с параметрами. Покажите, что мы все еще можем изменять как заданные, так и параметризованные переменные. <br></span>**
#
# Если мы создадим новый объект и забудем передать все параметры:

# %%
ball_4 = Ball('Серый')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-20208683f36a> in <module>
# ----> 1 ball_4 = Ball('Grey')
#
# TypeError: __init__() missing 1 required positional argument: 'radius'

# %% [markdown]
# ![image](./Images/lama3.png)
#
# **<span style = "color: teal"> Сообщение об ошибке относится к отсутствующему аргументу в `__init__()`, не в классе. это доказывает тот факт, что `__init __()` выполняется автоматически, и параметры, которые мы вводим при создании объекта, передаются в `__init__()`. Поэтому важно присвоить значения всем параметрам при создании объекта. <br></span>**
#
# **<span style = "color: teal"> `__init__()` передает переменные и параметры всему классу. Студенты могли заметить параметр self. Это специальный параметр, который относится к памяти каждого отдельного объекта, который был создан. С помощью `self` мы создаем переменные, которые существуют во всем классе. Мы можем использовать их в любых функциях класса. Что-то вроде локальной переменной в функции, но в классе. <br> </span>**
#
# Параметр self сохраняет наши переменные в каждом объекте. Это должен быть первый параметр в любой функции внутри класса.
#
# Для доступа к переменной в функции - `self.variableName`
#
#
# **<span style = "color: teal"> Скажите студентам, что можно назвать этот параметр (self) любым именем; он просто должен быть первым в любой функции внутри класса. Однако жители острова согласились называть переменную «self», и мы не уважаем людей, не соблюдающих наши правила! <br> </span>**
#
# **<span style = "color: teal"> Скажем: мы много говорим о функции, однако мы не создали никакой функции (кроме `__init __()`) в нашем классе. Важный словарный запас: любые функции внутри классов называются методами. Это помогает нам различать, что в классе, а что нет <br></span>**
#
# **<span style = "color: teal"> Во время урока в незаполненной тетради заполните текст, который здесь показан другим оттенком зеленого. </span>**
#
# **Метод** - любая функция в классе
#
# ## <CENTER> <span style = "color: Maroon"> Задача 2.1: </span> Обновите класс _Ball_!
#
# Скучно просто знать некоторые факты о мяче. Добавьте метод вычисления объема мяча в класс _Ball_. Затем создайте экземпляр шара и вызовите метод вычисления объема. Отобразите значение, возвращаемое методом.
#
# __<span style = "color: MidnightBlue"> P.S. </span>__ Напоминание: дизайн функций важен! <br>
# __<span style = "color: MidnightBlue"> P.S. </span>__ При вызове метода класса мы должны использовать круглые скобки после метода, как если бы мы вызывали функцию. (Пример: имяОбъекта.имяМетода(параметры, если требуются) <br>
#
#
# **<span style = "color: teal"> Вот несколько хитрое представление о параметрах. Итак, мы уже «параметризовали» класс - у нас есть уникальный объект. Студенты должны передать переменную, инициализированную в функции `__init__()`, в функцию громкости. Это означает, что их функции не нужны новые параметры! <br> </span>**
#
# **<span style = "color: teal"> Кроме того, учащиеся могут запутаться в лексике. Объясните: когда мы говорим «вызвать метод класса», мы вызываем функцию внутри этого класса. Также напомните студентам о правилах проектирования! Есть большая вероятность, что они забудут о комментариях. Скажите, остров злится, когда видит функцию без комментария. <br></span>**
#
# **<span style = "color: teal"> Если кому-то нужна помощь, попросите его предоставить общий доступ к экрану и направлять его (давать подсказки). <br> </span>**
#
# **<span style = "color: teal"> В решении я использую математическую библиотеку, а именно значение числа Пи. Впрочем, ничего страшного, если просто поставят 3.14. Если кто-то спросит, как установить значение Pi, скажите им, что нам нужно будет импортировать математическую библиотеку, а затем использовать `math.pi` (ну, pi - это атрибут переменной математического класса). <br></span>**

# %%
#Закончите код ниже
import math 

class Ball:
    """
    Это класс, представляющий мяч
    """
    def __init__(self, color, radius):
        """ Этот метод задает значения переменных в объекте """
        self.color = color
        self.radius = radius
        self.material = 'Кожа'
    
    def volume(self):
        """ Этот метод вычисляет объем мяча """
        return round((4/3)*math.pi*self.radius**3,2)
    
bigBall = Ball('Зеленый', 43)
bigBall.volume()
# Out:
# 333038.14

# %% [markdown]
# ## <CENTER> Код начинает выглядеть красиво, правда? Вы заработали эти <span style = "color: Goldenrod"> 4 монеты </span>!
#
# **<CENTER> <span style = "color: Goldenrod"> Добавьте их в свой кошелек**

# %%
#Ваш код тут

#

# %% [markdown]
# **<span style = "color: teal"> Мы получили некоторое представление о классах. Однако «классы» - огромная тема. Мы узнаем больше, когда начнем работать с классами и функциями аркадной библиотеки. Кроме того, сообщите учащимся, что они могут использовать поисковую систему для поиска дополнительной информации о классах (например, о наследовании). <br> </span>**
#
# # __<span style = "color: Maroon"> Библиотека arcade: класс _arcade.Window_ </span>__
#
# **<span style = "color: teal"> Теперь пора начать тесное сотрудничество с классами и функциями аркадной библиотеки! Мы уже сделали несколько рисунков в аркадной библиотеке. Вспомните, как мы использовали функцию для открытия окна (холста). Мы используем класс окна для более сложных игр - он имеет множество встроенных функций, которые мы рассмотрим! <br> </span>**
#
# Мы использовали функцию open_window() - `arcade.open_window(ШИРИНА_ЭКРАНА, ВЫСОТА_ЭКРАНА, "Пример рисования")` <br>
# Сейчас мы будем использовать класс Window - `window = arcade.Window (ШИРИНА_ЭКРАНА, ВЫСОТА_ЭКРАНА, "Пример рисования")` <br>
#
# Класс Window имеет множество встроенных методов, которые можно вызывать в любое время. Однако, чтобы заставить их работать, нам придется изменить их и приспособить к нашим потребностям.
#
# [Здесь] (https://learn.arcade.academy/chapters/15_window_class/window_class.html) вы можете узнать больше о классе _arcade.Window_.
#
# **<span style = "color: teal"> Сообщите учащимся, что, как уже упоминалось, на острове мы очень заботимся о дизайне. Мы покажем вам, как должна выглядеть игровая программа, и весь ваш код должен соответствовать одному и тому же шаблону. Это поможет вам оставаться организованным, а также поможет другим лучше понять ваш код. <br> </span>**
#
# Что необходимо в вашем игровом коде:
# - основная функция
# - Класс MyGame (наследник класса arcade.Window)
# - метод `__init()__` в каждом классе
# - Комментарии
#
# Обратите внимание на код ниже. Это суть вашей игры.
#
# **<span style="color:teal">Рассмотрите этот пример. <br>
# 1.Обратите внимание, что мы должны импортировать библиотеку только один раз <br>
# 2.Обратите внимание на то, что в этом классе _game_ мы используем все методы, выполняющие действие. Позже мы познакомимся с методами библиотеки аркад. Мы также можем написать свои собственные методы. Класс _MyGame_ является «наследником» класса _acrade.Window_. Не будем вдаваться в наследование. Просто скажите учащимся, что когда они создают класс _Game_ (где происходят реальные действия), они должны поместить _arcade.Window_ в круглые скобки после имени класса. <br>
# 3.В этом коде в классе _MyGame_ есть только один метод - функция инициализации. Там мы видим «super» - это часть разговора о наследовании. Идея состоит в том, что при инициализации _MyGame_ мы хотим также инициализировать параметры из родительского класса _arcade.Window_. Просто скажите студентам всегда использовать эту строку кода. <br>
# 4.Функция _main()_ - выполнила всю программу. Мы уже обсуждали это на прошлом уроке. <br>
# 5.Вызов функции _main()_ для запуска всей программы </span>**
# <img src="./Images/code1.png" width="100%">
#
# Запустите код в ячейке ниже

# %%
import arcade

class HangmanGame(arcade.Window):
    """
    Этот класс представляет игру
    """
    def __init__(self, width, height, title):
        """ Этот метод задает значения переменных в объекте """
        #Вызовите метод инициализации родительского класса
        super().__init__(width, height, title)
        

def main():
    window = HangmanGame(700, 700, "Палач")

    arcade.run()


main()

# %% [markdown]
# **<span style = "color: teal"> У нас получилось черное окно. Настроим цвет фона. Установка цвета фона является частью инициализации, поэтому мы делаем это в методе `__init __()`. <br> Обратите внимание, что мы начинаем код для их домашнего задания </span>**
#
# Возьмите код в ячейке выше и добавьте (вызовите) функцию _arcade.set_background_color_ в методе инициализации <br>
#
# __<span style = "color: MidnightBlue"> P.S. </span>__ убедитесь, что вы закрыли окно, которое было открыто с кодом в ячейке выше!
#
# **<span style = "color: teal"> Напомните учащимся закрыть открывшееся окно, прежде чем они снова запустят код библиотеки аркад! </span>**

# %%
#Ваш код тут
import arcade
class HangmanGame(arcade.Window):
    """
    Этот класс представляет игру
    """
    def __init__(self, width, height, title):
        """ Этот метод задает значения переменных в объекте """
        #Вызовите метод инициализации родительского класса
        super().__init__(width, height, title)
        
        # Установите цвет фона
        arcade.set_background_color(arcade.color.SKY_BLUE)

def main():
    window = HangmanGame(700, 700, "Hangman")

    arcade.run()


main()
#

# %% [markdown]
# **<span style = "color: teal"> По-прежнему черный! Напомните учащимся, что когда мы рисовали с помощью функции Arcade Window, мы должны были использовать `arcade.start_render()`, чтобы начать рисование. Фон также не появится до тех пор, пока не будет вызвана функция _start_render()_. <br>
# Для рисования мы используем специальный метод в классе arcade.Window - _on_draw_. </span>**
#
# _on_draw_ - встроенный метод в классе _arcade.Window_, в котором мы делаем все необходимые рисунки.
#
# **<span style = "color: teal"> Обратите внимание на то, что мы можем поместить часть кода рисования в отдельный метод (и мы это сделаем); однако этот метод по-прежнему должен вызываться внутри метода _on_draw_. </span>**
#
# **<span style = "color: teal"> Кроме того, отметьте, что для рисования мы используем те же функции, что и раньше. </span>**
#
# В качестве домашнего задания вам придется сделать игру Палач! Код, который мы разрабатываем, станет частью вашего домашнего задания.
#
# Запустите приведенный ниже код, и вы увидите, какой рисунок мы добавили в код!

# %%
import arcade

class HangmanGame(arcade.Window):

    def __init__(self, width, height, title):

        #Вызовите метод инициализации родительского класса
        super().__init__(width, height, title)

        # Установите цвет фона
        arcade.set_background_color(arcade.color.SKY_BLUE)

    def on_draw(self):
        """ Вызывается всякий раз, когда нам нужно нарисовать окно. """
        arcade.start_render()
        #Код отрисовки
        arcade.draw_rectangle_filled(150, 340, 10, 300, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(245, 490, 200, 10, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(350, 460, 10, 70, arcade.csscolor.BLACK)


def main():
    window = HangmanGame(700, 700, "Палач")

    arcade.run()


main()

# %% [markdown]
# Каждый метод (функция) делает только одно!
#
# **<span style = "color: teal"> Было бы лучше иметь код, задающий вид игры, в отдельном методе. Это то, что мы делаем в ячейке ниже. Обратите внимание на то, что для вызова созданного нами метода мы должны поставить перед ним _self._ Мы вызываем метод, который является «локальным» в этом классе. </span>**
#
# Обратите внимание на приведенный ниже код и запустите его.

# %%
import arcade 

class HangmanGame(arcade.Window):

    def __init__(self, width, height, title):

        #Вызовите метод инициализации родительского класса
        super().__init__(width, height, title)

        # Установите цвет фона
        arcade.set_background_color(arcade.color.SKY_BLUE)

    def draw_setup(self):
        """ Этот метод имеет код рисования для настройки холста перед запуском игры. """
        arcade.draw_rectangle_filled(150, 340, 10, 300, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(245, 490, 200, 10, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(350, 460, 10, 70, arcade.csscolor.BLACK)
        
    def on_draw(self):
        """ Вызывается всякий раз, когда нам нужно нарисовать окно. """
        arcade.start_render()
        #Код отрисовки
        self.draw_setup()


def main():
    window = HangmanGame(700, 700, "Палач")

    arcade.run()


main()

# %% [markdown]
# **<span style = "color: teal"> функция рисования не нова для учащихся. С этого момента мы просто делаем хорошо продуманный образ. Позже, когда у нас будут большие коды, студенты поймут, почему дизайн важен. </span>**
#
# # __<span style = "color: Maroon"> Библиотека arcade: взаимодействие с пользователем с клавиатуры </span>__
#
# **<span style = "color: teal"> Давайте узнаем что-то новое и захватывающее! Взаимодействие пользователя с игрой! <br> Пользователь может взаимодействовать с помощью клавиатуры или мыши. Сегодня мы покажем вам способ взаимодействия с пользователем с клавиатуры. Существует два метода взаимодействия с клавиатурой - _on_key_press_ и _on_key_release_. </span>**
#
# Функции класса _arcade.Windows_ для взаимодействия с пользователем через клавиатуру:
#
# ```python
#     def on_key_press(self, key, modifiers):
#         """ Вызывается всякий раз, когда пользователь нажимает клавишу. """
#         if key == arcade.key.LEFT:
#             'код, который сообщает, что должно произойти, когда нажата клавиша ВЛЕВО.'
#         elif key == arcade.key.X:
#             'код, который сообщает, что должно произойти при нажатии клавиши X.'
#         elif key == arcade.key.TAB or key == arcade.key.SPACE:
#             'код, который сообщает, что должно произойти при нажатии клавиши TAB или клавиши ПРОБЕЛ.'
#
#
#     def on_key_release(self, key, modifiers):
#         """ Вызывается всякий раз, когда пользователь отпускает клавишу. """
#         if key == arcade.key.LEFT:
#             'код, который сообщает, что должно произойти при отпускании клавиши ВЛЕВО'
#         elif key == arcade.key.X:
#             'код, который сообщает, что должно произойти при отпускании клавиши X'
#         elif key == arcade.key.TAB or key == arcade.key.SPACE:
#             'код, который сообщает, что должно произойти при отпускании клавиши TAB или клавиши ПРОБЕЛ'
# ```
#
# **<span style = "color: teal"> Обратите внимание, что это две отдельные функции. В нашем коде может быть только одна или обе. Это зависит от логики нашей игры. Обычно нам нужны обе, когда мы хотим написать код для движения персонажа (нажатие - перемещение, отпускание - остановка движения). <br> Обратите внимание, что параметры, которые у нас есть в методах _on_key_press_ и _on_key_release_, должны быть там. Мы не будем вдаваться в подробности почему (потому что это снова длинная история о наследовании классов). </span>**
#
# **<span style = "color: teal"> В игре Палач, если пользователь нажимает кнопку с буквой, содержащейся в слове, эта буква появляется на экране. Если такой буквы нет в слове, рисуем на холсте часть человека. </span>**
#
# Обратите внимание на код ниже. Мы добавили:
# 1. переменные в функцию инициализации
# 2. Метод _on_key_press_ и два условия (обновления переменных) для нажатий клавиш в этом методе
# 3. В метод _on_draw_ мы добавили код, который рисует вперед или букву на основе значений переменных.
#
# **<span style = "color: teal"> Объясните, что было добавлено. Обратите внимание, что мы добавили переменные в функцию инициализации, два условия для рисования и метод _on_key_press_. </span>**
#
# Запустите код. Нажмите кнопку «w» и какую-нибудь кнопку рядом с «w». Наблюдайте, что происходит.

# %%
import arcade

class HangmanGame(arcade.Window):

    def __init__(self, width, height, title):

        #Вызовите метод инициализации родительского класса
        super().__init__(width, height, title)

        # Установите цвет фона
        arcade.set_background_color(arcade.color.SKY_BLUE)
        
        self.counter = 0
        self.word = 'win'
        self.guess = ''
        self.gcount = 0

    def draw_setup(self):
        """ Этот метод имеет код рисования для настройки холста перед запуском игры. """
        arcade.draw_rectangle_filled(150, 340, 10, 300, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(245, 490, 200, 10, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(350, 460, 10, 70, arcade.csscolor.BLACK)
        
    def on_draw(self):
        """ Вызывается всякий раз, когда нам нужно нарисовать окно. """
        arcade.start_render()
        #Код отрисовки
        self.draw_setup()
        
        if self.counter>0:
            arcade.draw_circle_filled(350, 400, 30, arcade.csscolor.PEACH_PUFF)
            
        if self.word[0] in self.guess:
            arcade.draw_text_2 (self.word[0], 250, 450, arcade.csscolor.YELLOW, font_name = 'calibri', bold = True,
              font_size = 30) 
    
    def on_key_press(self, key, modifiers):
        """ Вызывается всякий раз, когда пользователь нажимает клавишу. """
        if key == arcade.key.W:
            self.guess = self.guess + 'w'
            self.gcount = self.gcount + 1 
        if key != arcade.key.W or key != arcade.key.I or key != arcade.key.N:
            self.counter = self.counter + 1


def main():
    window = HangmanGame(700, 700, "Палач")

    arcade.run()


main()

# %% [markdown]
# ![image](./Images/HW_v1.png)
# **<span style = "color: teal"> Объясните основную идею домашнего задания и до конца урока скажите учащимся, чтобы они начали обдумывать концепцию кода (какие методы они бы использовали, что нужно реализовать и как). Пожалуйста, оставьте это для открытого обсуждения, когда студенты задают вопросы, хороша какая-то идея или нет. Помогите им начать работу, дайте подсказки. Покажите код, предоставленный в решении (они увидят код, но не смогут его запомнить, и если они сделают тот же код, что и предоставленный код решения, это будет легко увидеть). </span>**
#
# # <span style = "color: Maroon"> Домашнее задание 2: </span> Игра Палач
# В ячейке выше мы запустили код игры с палачом. Ваша задача - закончить игру! Вы можете взять шаблон выше и продолжить работу над ним. В игре должны быть:
# 1. Строки для букв
# 2. Если пользователь нажимает на букву, которая находится в угаданном слове, буква помещается в нужное место.
# 3. Человек (палач) состоит из 7-10 частей, которые появляются одна за другой каждый раз, когда пользователь нажимает не ту букву.
# 4. Фраза «Вы выиграли», когда пользователь выигрывает, или фраза «Игра окончена», когда пользователь проигрывает.
#
# Ваш код должен **как можно точнее соответствовать правилам проектирования**. <br>
# Существуют ограничения, например, метод _on_key_press_, который вы использовали без возможности многоразового использования. Вы устанавливаете слово, которое пользователь должен угадать, и вводите ключи (arcade.key.W) в методе вручную. Следовательно, если вы измените слово, которое пользователь должен угадать, вам необходимо вручную изменить ключи в методе. Для этой домашней работы это нормально.
#
# Некоторые подсказки:
# - Вы можете использовать счетчик, чтобы отслеживать, сколько ошибочных предположений сделал пользователь. Это может помочь вам с рисунком и фразой «вы проиграли»
# - Используйте циклы, чтобы сделать код короче и удобнее для чтения.
#
# Жители острова очень рады видеть различные варианты кода для игры! <br> <br>
#
# <center> Вы можете заработать максимум <span style = "color: Goldenrod; font-weight: bold"> 15 монет </span> за это домашнее задание. <br>
#
# **<span style = "color: teal"> Однако, чтобы получить максимум, ваш код должен быть действительно хорошим! Это ваш шанс опередить своих одноклассников и стать лучшим учеником на острове. Помните, чем больше монет вы заработаете, тем больше у вас шансов попасть на корабль и вернуться домой! </span>**
#
# **<span style = "color: teal"> Учитель определяет количество монет, которое получит каждый ученик. Взгляните на критерии, например, <br> 1. Дизайн кода (возможность повторного использования класса/функции/метода, каждая функция/метод выполняет одно действие, комментарии, имена классов/функций/методов) <br> 2. Читаемость кода < br> 3. Использование циклов и условных операторов (если есть блок кода, который можно заменить циклом - это плохо) <br> 4. Общая логика - программа делает то, что должна делать <br> 5. Игровой дизайн (как выглядит игра в окне). </span>**
#
# [Здесь] (https://arcade.academy/arcade.html) вы можете найти все классы и функции/методы в библиотеке arcade. Там вы можете найти методы, которые включены в класс _arcade.Window_ (используйте _ctrl + F_, чтобы найти класс). Приглашаем вас поэкспериментировать и использовать в своем коде больше классов или функций/методов. <br>
#
# **<span style = "color: teal"> Сообщите учащимся, что они могут перейти на веб-сайт библиотеки аркад и изучить некоторые методы. Однако это может сбить их с толку, поэтому мы рекомендуем использовать методы и классы, которые мы уже представили. Тем не менее, знакомство с примерами, которые есть на веб-сайте, является хорошей практикой и может помочь студентам получить свежие идеи о том, как разработать свой игровой код. <br> Если есть время, зайдите на сайт и используйте _ctrl + F_, чтобы найти класс _arcade.Window_. Покажите учащимся, что в классе встроено множество методов. </span>**
#
# Сделайте игру с островным дизайном, и вы получите <span style = "color: Goldenrod; font-weight: bold"> дополнительные 2 монеты </span>
#
# Также в начале следующего урока будет быстрое голосование за лучший игровой дизайн! Первое место получает <span style = "color: Goldenrod; font-weight: bold"> дополнительную монету </span>!
#
#
#
# **<span style = "color: teal"> Объясните основную идею домашнего задания и скажите учащимся, чтобы до конца урока они начали обдумывать концепцию кода (какие методы они бы использовали, что нужно реализовать и как). Пусть это  будет в видк открытого обсуждения, когда студенты задают вопросы, высказывают свое мнение о том, хороша какая-то идея или нет. Помогите им начать работу, дайте подсказки. Покажите код, предоставленный в решении (они увидят код, но не смогут его запомнить, и если они сделают тот же код, что и предоставленный код решения, это будет легко увидеть). </span>**

# %%
import arcade

class HangmanGame(arcade.Window):

    def __init__(self, width, height, title):

        #Вызовите метод инициализации родительского класса
        super().__init__(width, height, title)

        arcade.set_background_color(arcade.color.SKY_BLUE)
        
        self.counter = 0
        self.word = 'win'
        self.guess = ''
        self.gcount = 0

    def draw_setup(self):
        """ Этот метод имеет код рисования для настройки холста перед запуском игры. """
        arcade.draw_rectangle_filled(150, 340, 10, 300, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(245, 490, 200, 10, arcade.csscolor.BLACK)
        arcade.draw_rectangle_filled(350, 460, 10, 70, arcade.csscolor.BLACK)
        
        for i in range(len(self.word)):
            arcade.draw_line (250+40*i, 550, 270+40*i, 550, arcade.csscolor.BLACK, line_width = 5)
        
        
    def draw_text(self):
        """ Этот метод отвечает за прорисовку букв слова"""
        for i in range(len(self.word)):
            if self.word[i] in self.guess:
                arcade.draw_text_2 (self.word[i], 250+40*i, 550, arcade.csscolor.YELLOW, font_name = 'calibri', 
                                    bold = True, font_size = 30) 
            
            
    def person_draw(self):
        """ Этот метод отвечает за рисование человека (палача)"""
        if self.counter>0:
            arcade.draw_circle_filled(350, 400, 30, arcade.csscolor.PEACH_PUFF)
        if self.counter >1:
            arcade.draw_rectangle_filled(350, 320, 20, 100, arcade.csscolor.BLACK)           
        if self.counter >2:
            arcade.draw_rectangle_filled(365, 340, 10, 45, arcade.csscolor.BLACK,210)
        if self.counter >3:
            arcade.draw_rectangle_filled(335, 340, 10, 45, arcade.csscolor.BLACK,330)
        if self.counter >4:
            arcade.draw_rectangle_filled(365, 250, 10, 60, arcade.csscolor.BLACK,30)
        if self.counter >5:
            arcade.draw_rectangle_filled(335, 250, 10, 60, arcade.csscolor.BLACK,330)
            
            
    def on_draw(self):
        """ Вызывается всякий раз, когда нам нужно нарисовать окно. """
        arcade.start_render()
        
        self.draw_setup()
        self.draw_text()
        self.person_draw()
        
        if self.counter >6:    
            arcade.draw_text_2 ('Игра окончена', 250, 350, arcade.csscolor.YELLOW, font_name = 'calibri', bold = True,
                    font_size = 50)
        if self.gcount == 3:
            arcade.draw_text_2 ('Вы выиграли', 250, 350, arcade.csscolor.YELLOW, font_name = 'calibri', bold = True,
                    font_size = 50)
    


    def on_key_press(self, key, modifiers):
        """ Вызывается всякий раз, когда пользователь нажимает клавишу. """
        if key == arcade.key.W:
            self.guess = self.guess + 'w'
            self.gcount = self.gcount + 1 
        elif key == arcade.key.I:
            self.guess = self.guess + 'i'
            self.gcount = self.gcount + 1 
        elif key == arcade.key.N:
            self.guess = self.guess + 'n'
            self.gcount = self.gcount + 1 
        else:
            self.counter = self.counter + 1


def main():
    window = HangmanGame(700, 700, "Палач")
    arcade.run()


main()
