# %% [markdown]
#
# <img src="./Images/HackGrade.jpg" width="80%">
#
# Уроки 14-16 посвящены вашему проекту хакатона! Вы должны разработать свою собственную игру. Вы отвечаете за идею, логику, правила, дизайн. Вы за все отвечаете. Вы можете вдохновиться играми, которые мы разработали в классе, [примерами игр](https://arcade.academy/sample_games.html) на веб-сайте библиотеки arcade или любой другой игрой, в которую вы играли. Может быть, вы хотите воссоздать одну из ваших любимых игр из детства? Вперед, продолжать! Все решения принимаете сами. Мы здесь, чтобы помочь вам с кодом и дать совет.
#
#
# ### <center> Вы можете заработать максимум <span style = "color: Goldenrod; font-weight: bold"> 70 монет </span> за этот финальный. <br>
#
# Если вы реализуете анимацию игрока/врага, как показано на [шаге 11](https://arcade.academy/examples/platform_tutorial/index.html#step-11-add-character-animations-and-better-keyboard-control ) этого примера платформера вы можете получить <span style = "color: Goldenrod; font-weight: bold"> от 10 до 30 дополнительных монет. </span>
#
# **<span style = "color: teal"> Эта градация от 10 до 30 монет зависит от сложности их анимации. Если есть только два состояния (например, обычный и лестничный), студент зарабатывает 10 монет. Если есть 6 состояний пробуждения, состояние лестницы, состояние прыжка, а также анимированные враги, то студент зарабатывает 30 монет. <br> </span>**
#
#
# **<span style = "color: teal"> Да, оценивать может быть сложно. Обязательно выставляйте оценки на основе сравнения учеников. Таким образом, за каждый из 4 баллов - если игра учеников выглядит лучше и интереснее - этот ученик получает больше, чем другие. Максимум отдавайте только за неординарную работу (все гладко и интересно). <br> </span>**
#
# Полезные ссылки:
# - [Книга из библиотеки arcade](https://learn.arcade.academy/chapters/index.html)
# - [Ресурсы библиотеки arcade](https://arcade.academy/resources.html#resources-music)
# - [Примеры кода](https://arcade.academy/examples/index.html)
# - [Пример платформера](https://arcade.academy/examples/platform_tutorial/index.html)
# - [Использование представлений для начальных и конечных экранов](https://arcade.academy/tutorials/views/index.html)
# - [Примеры игр, разработанные другими людьми с этой библиотекой](https://arcade.academy/sample_games.html)
# - любые другие ресурсы - поисковик может быть очень полезным!
#
# Эта записная книжка должна содержать ваш скрипт и код игры.
#
# ## __<span style = "color: Maroon"> Рабочий процесс уроков на протяжении хакатона </span>__
#
# Во время урока каждый ученик показывает экран и рассказывает, что сделано сегодня. Время, которое получает каждый ученик, зависит от размера группы. Время делится между всеми поровну. Учитель заранее сообщит, сколько времени есть у каждого ученика. Каждая презентация состоит из трех частей:
# - **Презентация проекта** - объясните общую идею игры вместе с кодом. Отметьте интересные функции, которые вы добавили, и покажите, как вы реализовали их в коде.
# - **Вопросы аудитории** - Учитель и другие ученики могут задавать вопросы и давать идеи/советы относительно кода и игры в целом.
# - **Вопросы докладчика** - это ваша возможность попросить учителя (или одноклассников) помочь с кодом (например, как реализовать некоторую логику или как исправить некоторую ошибку).
#
# ### <center> __<span style = "color: Maroon"> Урок 14 и Урок 15 </span>__
# Весь урок посвящен презентациям и вопросам и ответам. Время урока делится между всеми учениками поровну. Время для каждого студента распределяется следующим образом:
# - 1/3 на презентацию проекта
#     - Объяснение правил и идеи
#     - Показ игры (что у тебя сейчас есть)
#     - Просмотр кода и объяснение некоторых интересных особенностей
#     - Рассказ о своем видении игры на будущее (что будете делать на следующем уроке)
# - 1/3 для сессии вопросов и ответов аудитории
# - 1/3 для сессии вопросов и ответов докладчика
#
# # <span style = "color: Maroon"> Домашнее задание 14: </span> Принимайте советы и улучшайте свою игру.
#
# 1) Во время работы над игрой собирайте отзывы друзей и родственников о том, как сделать игру более интересной, увлекательной или более красивой. <br>
# 2) Реализуйте в игре предложения друзей и родственников <br>
# 3) Реализуйте предложения учителей и одноклассников в своей игре.
#
# # <span style = "color: Maroon"> Домашнее задание 15: </span> Завершите игру!
#
# 1) Убедитесь, что игра работает плавно и связанно <br>
# 2) Не забывайте про дизайн кода <br>
# 3) Завершите игру <br>
#
# ### <center> __<span style = "color: Maroon"> Урок 16: </span>__
#
# 1) Первые 50 минут урока ученики представляют свои итоговые проекты. Эти 50 минут делятся между ними поровну. Каждый тратит:
# - 2/3 на презентацию проекта
#     - Объяснение правил и идеи
#     - Показ игры
#     - Рассказ о том, какие отзывы ученик получил и как реализовал
#     - Просмотр кода и объяснение некоторых интересных особенностей
#     - Свое видение игры на будущее (что бы вы делали, если бы у вас было больше времени / что можно было бы улучшить)
# - 1/3 для сессии вопросов и ответов аудитории<br>
#
# **<span style = "color: teal"> При начислении баллов не забудьте вычесть баллы, если некоторые части того, что должно быть представлено, не были рассмотрены во время финальной презентации <br> </span>**
#
# 2) Следующие 5 минут - голосование за лучшую игру. <br>
# 3) Последние 5 минут - завершение курса. Посмотрим, у кого больше всего монет, и поздравим победителей! Надеемся, что все потрудились и у нас хватит монет, чтобы заплатить капитану корабля.
#
#
# **<span style = "color: teal"> Во время урока обязательно соблюдайте хронометраж, чтобы каждый учащийся имел одинаковое количество времени. Если кто-то закончит немного раньше, в конце урока будет дополнительное время, чтобы ответить на дополнительные вопросы других учащихся. Кроме того, во время презентации соблюдайте время для каждой части презентации. В общем, оставляйте ~ 1/3 представленного времени для каждой части. Сообщайте учащимся, когда у них остается 10, 5, 3, 1 минута. <br> </span>**

# %% [markdown]
# # __ <span style = "color: Maroon"> Сценарий игры </span> __
#
# Сценарий должен состоять минимум из 300 слов. В сценарии необходимо описать:
# - Общая идея игры
# - Правила игры
# - Функции, которые вы планируете включить в свою игру
# - Общее представление о дизайне (цвета, тема и т. Д.)
#
# По мере того, как вы работаете над игрой, ваш сценарий или правила игры могут измениться. Если это произошло, обновите описание!

# %% [markdown]
# # <center> Напишите свой сценарий тут

# %% [markdown]
# # __<span style = "color: Maroon"> Код игры </span>__
#
# В ячейке ниже должен быть код вашей игры.
#
# Вы можете использовать / создавать несколько ячеек с кодом игры, чтобы использовать их для тестирования некоторых частей кода.
#
# __<span style = "color: midnightblue"> P.S. </span>__ Для создания новой ячейки используйте комбинацию клавиш ESC + B (чтобы создать ячейку под текущей ячейкой) или ESC + A (чтобы создать ячейку над текущей).

# %%
# Ваш код игры тут

#

# %% [markdown]
# # __<span style = "color: Maroon"> Голосование за лучшую игру </span>__
# **<span style = "color: teal"> Используется для голосования на уроке 16. <br> </span>**
# ![image](./Images/vote.png)
# **<span style = "color: teal"> Поскольку это более серьезные игры, чем то, за что мы голосовали раньше, голосование также более серьезное. Каждый ученик, проголосовавший за игру, может поставить оценку от 1 до 5. Рабочий процесс выглядит следующим образом: мы смотрим на работу ученика №1 и спрашиваем других учеников, как они оценивают эту игру. Рейтинги суммируются в ячейке ниже и печатается общая сумма. Затем мы смотрим на работу ученика №2 и так далее. <br> </span>**
#
# Голосование происходит в конце урока 16. <br>
# Каждый ученик может оценить игру другого ученика от 1 до 5. Следуйте инструкциям учителя.

# %%
name1 = 0
print("____ получает", name1, "очков за его/ее игру")
name2 = 0
print("____ получает", name2, "очков за его/ее игру")
name3 = 0
print("____ получает", name3, "очков за его/ее игру")
name4 = 0
print("____ получает", name4, "очков за его/ее игру")
name5 = 0
print("____ получает", name5, "очков за его/ее игру")
# Out:
# ____ получает 0 очков за его/ее игру
# ____ получает 0 очков за его/ее игру
# ____ получает 0 очков за его/ее игру
# ____ получает 0 очков за его/ее игру
# ____ получает 0 очков за его/ее игру
